# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from keras import models, layers

# %%
bitcoinpricdata = pd.read_csv("bitstampUSD_1-min_data_2012-01-01_to_2020-09-14.csv")
bitcoinpricdata.head()
# Out:
#     Timestamp  Open  High  ...  Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0  1325317920  4.39  4.39  ...      0.455581                2.0            4.39
# 1  1325317980   NaN   NaN  ...           NaN                NaN             NaN
# 2  1325318040   NaN   NaN  ...           NaN                NaN             NaN
# 3  1325318100   NaN   NaN  ...           NaN                NaN             NaN
# 4  1325318160   NaN   NaN  ...           NaN                NaN             NaN
#
# [5 rows x 8 columns]

# %%
bitcoinpricdata
# Out:
#           Timestamp      Open  ...  Volume_(Currency)  Weighted_Price
# 0        1325317920      4.39  ...           2.000000        4.390000
# 1        1325317980       NaN  ...                NaN             NaN
# 2        1325318040       NaN  ...                NaN             NaN
# 3        1325318100       NaN  ...                NaN             NaN
# 4        1325318160       NaN  ...                NaN             NaN
# ...             ...       ...  ...                ...             ...
# 4572252  1600041360  10324.35  ...         837.754188    10324.419779
# 4572253  1600041420  10331.41  ...        5918.028741    10331.444396
# 4572254  1600041480  10327.20  ...       25711.238323    10326.175283
# 4572255  1600041540  10330.02  ...       47253.747619    10333.972651
# 4572256  1600041600  10338.82  ...       13349.565122    10332.429402
#
# [4572257 rows x 8 columns]

# %%
print('Shape of DataFrame: ',  bitcoinpricdata.shape)
# Out:
# Shape of DataFrame:  (4572257, 8)

# %%
bitcoinpricdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572257 entries, 0 to 4572256
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          int64
#  1   Open               float64
#  2   High               float64
#  3   Low                float64
#  4   Close              float64
#  5   Volume_(BTC)       float64
#  6   Volume_(Currency)  float64
#  7   Weighted_Price     float64
# dtypes: float64(7), int64(1)
# memory usage: 279.1 MB

# %%
bitcoinpricdata.tail()
# Out:
#           Timestamp      Open  ...  Volume_(Currency)  Weighted_Price
# 4572252  1600041360  10324.35  ...         837.754188    10324.419779
# 4572253  1600041420  10331.41  ...        5918.028741    10331.444396
# 4572254  1600041480  10327.20  ...       25711.238323    10326.175283
# 4572255  1600041540  10330.02  ...       47253.747619    10333.972651
# 4572256  1600041600  10338.82  ...       13349.565122    10332.429402
#
# [5 rows x 8 columns]

# %%
bitcoinpricdata['Timestamp'] = pd.to_datetime(bitcoinpricdata['Timestamp'],unit='s')

# %%
bitcoinpricdata.set_index("Timestamp").Weighted_Price.plot(figsize=(14,7), title="Bitcoin Weighted Price")

# %%
#calculating missing values in the dataset

missing_values = bitcoinpricdata.isnull().sum()
missing_per = (missing_values/bitcoinpricdata.shape[0])*100
missing_table = pd.concat([missing_values,missing_per], axis=1, ignore_index=True) 
missing_table.rename(columns={0:'Total Missing Values',1:'Missing %'}, inplace=True)
missing_table
# Out:
#                    Total Missing Values  Missing %
# Timestamp                             0   0.000000
# Open                            1241716  27.157616
# High                            1241716  27.157616
# Low                             1241716  27.157616
# Close                           1241716  27.157616
# Volume_(BTC)                    1241716  27.157616
# Volume_(Currency)               1241716  27.157616
# Weighted_Price                  1241716  27.157616

# %%
def fill_missing_values(df):
    ### function to impute missing values using interpolation ###
    df['Open'] = df['Open'].interpolate()
    df['Close'] = df['Close'].interpolate()
    df['Weighted_Price'] = df['Weighted_Price'].interpolate()

    df['Volume_(BTC)'] = df['Volume_(BTC)'].interpolate()
    df['Volume_(Currency)'] = df['Volume_(Currency)'].interpolate()
    df['High'] = df['High'].interpolate()
    df['Low'] = df['Low'].interpolate()

    print(df.head())
    print(df.isnull().sum())

# %%
fill_missing_values(bitcoinpricdata)
# Out:
#             Timestamp  Open  ...  Volume_(Currency)  Weighted_Price
# 0 2011-12-31 07:52:00  4.39  ...           2.000000            4.39
# 1 2011-12-31 07:53:00  4.39  ...           2.436653            4.39
# 2 2011-12-31 07:54:00  4.39  ...           2.873305            4.39
# 3 2011-12-31 07:55:00  4.39  ...           3.309958            4.39
# 4 2011-12-31 07:56:00  4.39  ...           3.746611            4.39
#
# [5 rows x 8 columns]
# Timestamp            0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume_(BTC)         0
# Volume_(Currency)    0
# Weighted_Price       0
# dtype: int64

# %%
bitcoinpricdata = bitcoinpricdata.set_index('Timestamp')
bitcoinpricdata.head()
# Out:
#                      Open  High  ...  Volume_(Currency)  Weighted_Price
# Timestamp                        ...
# 2011-12-31 07:52:00  4.39  4.39  ...           2.000000            4.39
# 2011-12-31 07:53:00  4.39  4.39  ...           2.436653            4.39
# 2011-12-31 07:54:00  4.39  4.39  ...           2.873305            4.39
# 2011-12-31 07:55:00  4.39  4.39  ...           3.309958            4.39
# 2011-12-31 07:56:00  4.39  4.39  ...           3.746611            4.39
#
# [5 rows x 7 columns]

# %%
import seaborn as sns

sns.kdeplot(bitcoinpricdata['Weighted_Price'], shade=True)

# %%
onehr_data = bitcoinpricdata.resample('1H').mean()
onehr_data = onehr_data.reset_index()

onehr_data.head()
# Out:
#             Timestamp  Open  ...  Volume_(Currency)  Weighted_Price
# 0 2011-12-31 07:00:00  4.39  ...           3.528285            4.39
# 1 2011-12-31 08:00:00  4.39  ...          18.374477            4.39
# 2 2011-12-31 09:00:00  4.39  ...          44.573640            4.39
# 3 2011-12-31 10:00:00  4.39  ...          70.772803            4.39
# 4 2011-12-31 11:00:00  4.39  ...          96.971967            4.39
#
# [5 rows x 8 columns]

# %%
bitstamp_24hr = bitcoinpricdata.resample("24H").mean() #daily resampling

# %%
bitstamp_24hr
# Out:
#                     Open          High  ...  Volume_(Currency)  Weighted_Price
# Timestamp                               ...
# 2011-12-31      4.476415      4.478946  ...          79.495594        4.477370
# 2012-01-01      4.765576      4.765576  ...          32.971105        4.765576
# 2012-01-02      5.006549      5.006549  ...          75.932706        5.006549
# 2012-01-03      5.206530      5.206530  ...          40.795994        5.206530
# 2012-01-04      5.202511      5.241699  ...          72.860096        5.216680
# ...                  ...           ...  ...                ...             ...
# 2020-09-10  10338.749108  10343.543889  ...       73535.577979    10339.348363
# 2020-09-11  10302.363316  10306.010990  ...       37580.589410    10303.176693
# 2020-09-12  10372.654476  10375.351788  ...       18139.389649    10373.142987
# 2020-09-13  10395.358045  10398.491701  ...       31176.896275    10395.798156
# 2020-09-14  10338.820000  10338.820000  ...       13349.565122    10332.429402
#
# [3181 rows x 7 columns]

# %%
import plotly.express as px

bitstamp_24hr.reset_index(inplace=True)
fig = px.line(bitstamp_24hr, x='Timestamp', y='Weighted_Price', title='Weighted Price with Range Slider and Selectors')
fig.update_layout(hovermode="x")

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=2, label="2y", step="year", stepmode="backward"),
            dict(step="all")
            
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e933361b-f4af-4d3b-b903-4f7b2879c0ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e933361b-f4af-4d3b-b903-4f7b2879c0ab")) {                    Plotly.newPlot(                        "e933361b-f4af-4d3b-b903-4f7b2879c0ab",                        [{"hovertemplate":"Timestamp=%{x}<br>Weighted_Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2011-12-31T00:00:00","2012-01-01T00:00:00","2012-01-02T00:00:00","2012-01-03T00:00:00","2012-01-04T00:00:00","2012-01-05T00:00:00","2012-01-06T00:00:00","2012-01-07T00:00:00","2012-01-08T00:00:00","2012-01-09T00:00:00","2012-01-10T00:00:00","2012-01-11T00:00:00","2012-01-12T00:00:00","2012-01-13T00:00:00","2012-01-14T00:00:00","2012-01-15T00:00:00","2012-01-16T00:00:00","2012-01-17T00:00:00","2012-01-18T00:00:00","2012-01-19T00:00:00","2012-01-20T00:00:00","2012-01-21T00:00:00","2012-01-22T00:00:00","2012-01-23T00:00:00","2012-01-24T00:00:00","2012-01-25T00:00:00","2012-01-26T00:00:00","2012-01-27T00:00:00","2012-01-28T00:00:00","2012-01-29T00:00:00","2012-01-30T00:00:00","2012-01-31T00:00:00","2012-02-01T00:00:00","2012-02-02T00:00:00","2012-02-03T00:00:00","2012-02-04T00:00:00","2012-02-05T00:00:00","2012-02-06T00:00:00","2012-02-07T00:00:00","2012-02-08T00:00:00","2012-02-09T00:00:00","2012-02-10T00:00:00","2012-02-11T00:00:00","2012-02-12T00:00:00","2012-02-13T00:00:00","2012-02-14T00:00:00","2012-02-15T00:00:00","2012-02-16T00:00:00","2012-02-17T00:00:00","2012-02-18T00:00:00","2012-02-19T00:00:00","2012-02-20T00:00:00","2012-02-21T00:00:00","2012-02-22T00:00:00","2012-02-23T00:00:00","2012-02-24T00:00:00","2012-02-25T00:00:00","2012-02-26T00:00:00","2012-02-27T00:00:00","2012-02-28T00:00:00","2012-02-29T00:00:00","2012-03-01T00:00:00","2012-03-02T00:00:00","2012-03-03T00:00:00","2012-03-04T00:00:00","2012-03-05T00:00:00","2012-03-06T00:00:00","2012-03-07T00:00:00","2012-03-08T00:00:00","2012-03-09T00:00:00","2012-03-10T00:00:00","2012-03-11T00:00:00","2012-03-12T00:00:00","2012-03-13T00:00:00","2012-03-14T00:00:00","2012-03-15T00:00:00","2012-03-16T00:00:00","2012-03-17T00:00:00","2012-03-18T00:00:00","2012-03-19T00:00:00","2012-03-20T00:00:00","2012-03-21T00:00:00","2012-03-22T00:00:00","2012-03-23T00:00:00","2012-03-24T00:00:00","2012-03-25T00:00:00","2012-03-26T00:00:00","2012-03-27T00:00:00","2012-03-28T00:00:00","2012-03-29T00:00:00","2012-03-30T00:00:00","2012-03-31T00:00:00","2012-04-01T00:00:00","2012-04-02T00:00:00","2012-04-03T00:00:00","2012-04-04T00:00:00","2012-04-05T00:00:00","2012-04-06T00:00:00","2012-04-07T00:00:00","2012-04-08T00:00:00","2012-04-09T00:00:00","2012-04-10T00:00:00","2012-04-11T00:00:00","2012-04-12T00:00:00","2012-04-13T00:00:00","2012-04-14T00:00:00","2012-04-15T00:00:00","2012-04-16T00:00:00","2012-04-17T00:00:00","2012-04-18T00:00:00","2012-04-19T00:00:00","2012-04-20T00:00:00","2012-04-21T00:00:00","2012-04-22T00:00:00","2012-04-23T00:00:00","2012-04-24T00:00:00","2012-04-25T00:00:00","2012-04-26T00:00:00","2012-04-27T00:00:00","2012-04-28T00:00:00","2012-04-29T00:00:00","2012-04-30T00:00:00","2012-05-01T00:00:00","2012-05-02T00:00:00","2012-05-03T00:00:00","2012-05-04T00:00:00","2012-05-05T00:00:00","2012-05-06T00:00:00","2012-05-07T00:00:00","2012-05-08T00:00:00","2012-05-09T00:00:00","2012-05-10T00:00:00","2012-05-11T00:00:00","2012-05-12T00:00:00","2012-05-13T00:00:00","2012-05-14T00:00:00","2012-05-15T00:00:00","2012-05-16T00:00:00","2012-05-17T00:00:00","2012-05-18T00:00:00","2012-05-19T00:00:00","2012-05-20T00:00:00","2012-05-21T00:00:00","2012-05-22T00:00:00","2012-05-23T00:00:00","2012-05-24T00:00:00","2012-05-25T00:00:00","2012-05-2 ...

# %%
fill_missing_values(bitstamp_24hr)
# Out:
#    Timestamp      Open  ...  Volume_(Currency)  Weighted_Price
# 0 2011-12-31  4.476415  ...          79.495594        4.477370
# 1 2012-01-01  4.765576  ...          32.971105        4.765576
# 2 2012-01-02  5.006549  ...          75.932706        5.006549
# 3 2012-01-03  5.206530  ...          40.795994        5.206530
# 4 2012-01-04  5.202511  ...          72.860096        5.216680
#
# [5 rows x 8 columns]
# Timestamp            0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume_(BTC)         0
# Volume_(Currency)    0
# Weighted_Price       0
# dtype: int64

# %%
bitstamp_24hr = bitstamp_24hr.set_index("Timestamp")

# %%
bitstamp_24hr.iloc[0:2923]
# Out:
#                    Open         High  ...  Volume_(Currency)  Weighted_Price
# Timestamp                             ...
# 2011-12-31     4.476415     4.478946  ...          79.495594        4.477370
# 2012-01-01     4.765576     4.765576  ...          32.971105        4.765576
# 2012-01-02     5.006549     5.006549  ...          75.932706        5.006549
# 2012-01-03     5.206530     5.206530  ...          40.795994        5.206530
# 2012-01-04     5.202511     5.241699  ...          72.860096        5.216680
# ...                 ...          ...  ...                ...             ...
# 2019-12-27  7191.460191  7194.926622  ...       20193.740928     7191.867431
# 2019-12-28  7298.360260  7301.238063  ...        8231.113729     7298.773444
# 2019-12-29  7344.712240  7347.241653  ...       13675.196606     7345.160715
# 2019-12-30  7297.666851  7300.180139  ...       18946.564199     7297.894007
# 2019-12-31  7198.665111  7201.303448  ...       13247.666961     7199.125109
#
# [2923 rows x 7 columns]

# %%
bitstamp_24hr.drop(['Open','Close','Volume_(BTC)','Volume_(Currency)', 'High','Low'],axis=1, inplace=True)

# %%
bitstamp_24hr
# Out:
#             Weighted_Price
# Timestamp
# 2011-12-31        4.477370
# 2012-01-01        4.765576
# 2012-01-02        5.006549
# 2012-01-03        5.206530
# 2012-01-04        5.216680
# ...                    ...
# 2020-09-10    10339.348363
# 2020-09-11    10303.176693
# 2020-09-12    10373.142987
# 2020-09-13    10395.798156
# 2020-09-14    10332.429402
#
# [3181 rows x 1 columns]

# %%
price_series = bitstamp_24hr.reset_index().Weighted_Price.values
price_series
# Out:
# array([4.47737025e+00, 4.76557639e+00, 5.00654859e+00, ...,
#        1.03731430e+04, 1.03957982e+04, 1.03324294e+04])

# %%
time_series = bitstamp_24hr.reset_index().Timestamp.values
time_series
# Out:
# array(['2011-12-31T00:00:00.000000000', '2012-01-01T00:00:00.000000000',
#        '2012-01-02T00:00:00.000000000', ...,
#        '2020-09-12T00:00:00.000000000', '2020-09-13T00:00:00.000000000',
#        '2020-09-14T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
price_series.shape
# Out:
# (3181,)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))
price_series_scaled = scaler.fit_transform(price_series.reshape(-1,1))

# %%
price_series_scaled.shape
# Out:
# (3181, 1)

# %%
train_data, test_data = price_series_scaled[0:2923], price_series_scaled[2923:]

# %%
train_data
# Out:
# array([[6.08556702e-06],
#        [2.11105388e-05],
#        [3.36730766e-05],
#        ...,
#        [3.82695922e-01],
#        [3.80231780e-01],
#        [3.75082688e-01]])

# %%
test_data
# Out:
# array([[0.37491768],
#        [0.36849274],
#        [0.37605608],
#        [0.38148647],
#        [0.38712802],
#        [0.39252016],
#        [0.41317751],
#        [0.42912486],
#        [0.41155098],
#        [0.41099899],
#        [0.42274381],
#        [0.42265234],
#        [0.42219322],
#        [0.44679055],
#        [0.45560518],
#        [0.45199251],
#        [0.46129351],
#        [0.46332625],
#        [0.46101572],
#        [0.4504458 ],
#        [0.45052091],
#        [0.45153659],
#        [0.43955893],
#        [0.4368209 ],
#        [0.43359932],
#        [0.43921931],
#        [0.4545379 ],
#        [0.47113893],
#        [0.48622488],
#        [0.48830269],
#        [0.48681115],
#        [0.48838555],
#        [0.48862304],
#        [0.48619293],
#        [0.47954694],
#        [0.48996769],
#        [0.5049084 ],
#        [0.50946061],
#        [0.51134823],
#        [0.5253092 ],
#        [0.51705421],
#        [0.51888869],
#        [0.53904608],
#        [0.53602273],
#        [0.53476191],
#        [0.52860138],
#        [0.51617516],
#        [0.50653339],
#        [0.51309041],
#        [0.52625357],
#        [0.49932132],
#        [0.50492903],
#        [0.50339618],
#        [0.51430925],
#        [0.50728602],
#        [0.49451491],
#        [0.4707099 ],
#        [0.45834053],
#        [0.45324947],
#        [0.45260899],
#        [0.44589374],
#        [0.455809  ],
#        [0.45808651],
#        [0.45651721],
#        [0.46999603],
#        [0.47408441],
#        [0.47178328],
#        [0.44656146],
#        [0.41068915],
#        [0.41413242],
#        [0.40901757],
#        [0.34733263],
#        [0.27577512],
#        [0.28180538],
#        [0.27606405],
#        [0.25978613],
#        [0.27677838],
#        [0.27536464],
#        [0.30003419],
#        [0.33136689],
#        [0.32139695],
#        [0.31984976],
#        [0.31808253],
#        [0.34663098],
#        [0.34708672],
#        [0.34760617],
#        [0.34864959],
#        [0.32445119],
#        [0.31813882],
#        [0.32679673],
#        [0.3361156 ],
#        [0.32863986],
#        [0.3502992 ],
#        [0.35500027],
#        [0.35286502],
#        [0.35411551],
#        [0.36942446],
#        [0.38126802],
#        [0.38043726],
#        [0.38060303],
#        [0.36346653],
#        [0.35802582],
#        [0.36198449],
#        [0.35175755],
#        [0.35868621],
#        [0.35436989],
#        [0.3601399 ],
#        [0.36845379],
#        [0.37264567],
#        [0.37345157],
#        [0.36743741],
#        [0.35779752],
#        [0.36472721],
#        [0.38003036],
#        [0.39189757],
#        [0.39321675],
#        [0.39605542],
#        [0.40202759],
#        [0.40280027],
#        [0.4295975 ],
#        [0.46345552],
#        [0.45771891],
#        [0.46236238],
#        [0.46795052],
#        [0.45711252],
#        [0.46536472],
#        [0.47744693],
#        [0.49454781],
#        [0.51716243],
#        [0.50688149],
#        [0.45267649],
#        [0.45368543],
#        [0.4571943 ],
#        [0.4713325 ],
#        [0.49903938],
#        [0.49626919],
#        [0.49000425],
#        [0.50152879],
#        [0.50659712],
#        [0.5039117 ],
#        [0.50401188],
#        [0.48358025],
#        [0.4755041 ],
#        [0.47976318],
#        [0.47541622],
#        [0.45956078],
#        [0.46165218],
#        [0.4703906 ],
#        [0.48566523],
#        [0.49265633],
#        [0.49540672],
#        [0.4974875 ],
#        [0.49944784],
#        [0.51485079],
#        [0.49772655],
#        [0.50544724],
#        [0.50767228],
#        [0.50214577],
#        [0.50135107],
#        [0.50680857],
#        [0.50611375],
#        [0.51004671],
#        [0.50252873],
#        [0.49040564],
#        [0.49122569],
#        [0.49005254],
#        [0.48172079],
#        [0.49471156],
#        [0.49206669],
#        [0.49014937],
#        [0.48599147],
#        [0.48468632],
#        [0.48714124],
#        [0.49403472],
#        [0.5022402 ],
#        [0.49195282],
#        [0.4810431 ],
#        [0.47841309],
#        [0.47456507],
#        [0.47184632],
#        [0.47502431],
#        [0.47683754],
#        [0.47894088],
#        [0.47766879],
#        [0.47386645],
#        [0.47373395],
#        [0.47231665],
#        [0.48004879],
#        [0.4830018 ],
#        [0.48698126],
#        [0.48615687],
#        [0.47939465],
#        [0.48143067],
#        [0.48199038],
#        [0.48347641],
#        [0.48044579],
#        [0.48053383],
#        [0.47585522],
#        [0.47598822],
#        [0.47740834],
#        [0.47704717],
#        [0.47823839],
#        [0.48499877],
#        [0.48802855],
#        [0.49717381],
#        [0.49801705],
#        [0.50126549],
#        [0.51243327],
#        [0.54377873],
#        [0.5724569 ],
#        [0.57823839],
#        [0.57498307],
#        [0.58345498],
#        [0.60499713],
#        [0.59060117],
#        [0.58651106],
#        [0.58593457],
#        [0.59747987],
#        [0.61262317],
#        [0.61058339],
#        [0.60893581],
#        [0.60829921],
#        [0.62015157],
#        [0.60623057],
#        [0.59740935],
#        [0.60195372],
#        [0.61260273],
#        [0.6189534 ],
#        [0.61759268],
#        [0.62824852],
#        [0.63393972],
#        [0.61480937],
#        [0.61490586],
#        [0.61203588],
#        [0.60242505],
#        [0.60560053],
#        [0.61149789],
#        [0.59976336],
#        [0.59427395],
#        [0.59128622],
#        [0.59629928],
#        [0.59967768],
#        [0.60496833],
#        [0.60894375],
#        [0.61883331],
#        [0.60330389],
#        [0.57528358],
#        [0.54149822],
#        [0.53513181],
#        [0.53161105],
#        [0.5294621 ],
#        [0.52880855],
#        [0.53090647],
#        [0.53879109],
#        [0.53690536],
#        [0.54055289],
#        [0.54173397],
#        [0.53843038]])

# %%
train_data.shape, test_data.shape
# Out:
# ((2923, 1), (258, 1))

# %%
def windowed_dataset(series, time_step):
    dataX, dataY = [], []
    for i in range(len(series)- time_step-1):
        a = series[i : (i+time_step), 0]
        dataX.append(a)
        dataY.append(series[i+ time_step, 0])
        
    return np.array(dataX), np.array(dataY)

# %%
len(train_data)
# Out:
# 2923

# %%
X_train, y_train = windowed_dataset(train_data, time_step=100)
X_test, y_test = windowed_dataset(test_data, time_step=100)

# %%
X_test[0]
# Out:
# array([0.37491768, 0.36849274, 0.37605608, 0.38148647, 0.38712802,
#        0.39252016, 0.41317751, 0.42912486, 0.41155098, 0.41099899,
#        0.42274381, 0.42265234, 0.42219322, 0.44679055, 0.45560518,
#        0.45199251, 0.46129351, 0.46332625, 0.46101572, 0.4504458 ,
#        0.45052091, 0.45153659, 0.43955893, 0.4368209 , 0.43359932,
#        0.43921931, 0.4545379 , 0.47113893, 0.48622488, 0.48830269,
#        0.48681115, 0.48838555, 0.48862304, 0.48619293, 0.47954694,
#        0.48996769, 0.5049084 , 0.50946061, 0.51134823, 0.5253092 ,
#        0.51705421, 0.51888869, 0.53904608, 0.53602273, 0.53476191,
#        0.52860138, 0.51617516, 0.50653339, 0.51309041, 0.52625357,
#        0.49932132, 0.50492903, 0.50339618, 0.51430925, 0.50728602,
#        0.49451491, 0.4707099 , 0.45834053, 0.45324947, 0.45260899,
#        0.44589374, 0.455809  , 0.45808651, 0.45651721, 0.46999603,
#        0.47408441, 0.47178328, 0.44656146, 0.41068915, 0.41413242,
#        0.40901757, 0.34733263, 0.27577512, 0.28180538, 0.27606405,
#        0.25978613, 0.27677838, 0.27536464, 0.30003419, 0.33136689,
#        0.32139695, 0.31984976, 0.31808253, 0.34663098, 0.34708672,
#        0.34760617, 0.34864959, 0.32445119, 0.31813882, 0.32679673,
#        0.3361156 , 0.32863986, 0.3502992 , 0.35500027, 0.35286502,
#        0.35411551, 0.36942446, 0.38126802, 0.38043726, 0.38060303])

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2822, 100), (2822,), (157, 100), (157,))

# %%
#reshape inputs to be [samples, timesteps, features] which is requred for LSTM

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)


print(X_train.shape) 
print(X_test.shape)
# Out:
# (2822, 100, 1)
# (157, 100, 1)

# %%
print(y_train.shape) 
print(y_test.shape)
# Out:
# (2822,)
# (157,)

# %%
#Create Stacked LSTM Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %%
# Initialising the LSTM
model = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_2 (LSTM)               (None, 100, 50)           20200
#
#  dropout_2 (Dropout)         (None, 100, 50)           0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the RNN to the Training set
history = model.fit(X_train, y_train, validation_split=0.1, epochs = 100, batch_size = 32, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 25s 229ms/step - loss: 0.0055 - val_loss: 0.0420
# Epoch 2/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0169 - val_loss: 0.0578
# Epoch 3/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0200 - val_loss: 0.0117
# Epoch 4/100
# 80/80 [==============================] - 17s 209ms/step - loss: 0.0223 - val_loss: 0.0176
# Epoch 5/100
# 80/80 [==============================] - 17s 209ms/step - loss: 0.0164 - val_loss: 0.0036
# Epoch 6/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0083 - val_loss: 0.0121
# Epoch 7/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0081 - val_loss: 0.0056
# Epoch 8/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 9/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 10/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 11/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 12/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 13/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 14/100
# 80/80 [==============================] - 17s 209ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 15/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 16/100
# 80/80 [==============================] - 16s 206ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 17/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 18/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 19/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0024 - val_loss: 0.0049
# Epoch 20/100
# 80/80 [==============================] - 16s 206ms/step - loss: 0.0027 - val_loss: 0.0073
# Epoch 21/100
# 80/80 [==============================] - 16s 205ms/step - loss: 0.0031 - val_loss: 0.0054
# Epoch 22/100
# 80/80 [==============================] - 17s 209ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 23/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 24/100
# 80/80 [==============================] - 16s 206ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 25/100
# 80/80 [==============================] - 17s 206ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 26/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 27/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0018 - val_loss: 0.0047
# Epoch 28/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0023 - val_loss: 0.0081
# Epoch 29/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0032 - val_loss: 0.0067
# Epoch 30/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 31/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 32/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 33/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 34/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 35/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 36/100
# 80/80 [==============================] - 16s 205ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 37/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 38/100
# 80/80 [==============================] - 17s 209ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 39/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 40/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 41/100
# 80/80 [==============================] - 16s 206ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 42/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 43/100
# 80/80 [==============================] - 17s 209ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 44/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 45/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 46/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0016 - val_loss: 8.5983e-04
# Epoch 47/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0013 - val_loss: 8.1699e-04
# Epoch 48/100
# 80/80 [==============================] - 16s 205ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 49/100
# 80/80 [==============================] - 16s 203ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 50/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 51/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 52/100
# 80/80 [==============================] - 16s 206ms/step - loss: 0.0017 - val_loss: 0.0059
# Epoch 53/100
# 80/80 [==============================] - 16s 206ms/step - loss: 0.0022 - val_loss: 0.0062
# Epoch 54/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0023 - val_loss: 0.0073
# Epoch 55/100
# 80/80 [==============================] - 17s 209ms/step - loss: 0.0026 - val_loss: 0.0074
# Epoch 56/100
# 80/80 [==============================] - 16s 204ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 57/100
# 80/80 [==============================] - 16s 206ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 58/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 59/100
# 80/80 [==============================] - 17s 214ms/step - loss: 0.0016 - val_loss: 9.5280e-04
# Epoch 60/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0014 - val_loss: 6.1256e-04
# Epoch 61/100
# 80/80 [==============================] - 17s 215ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 62/100
# 80/80 [==============================] - 17s 216ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 63/100
# 80/80 [==============================] - 17s 216ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 64/100
# 80/80 [==============================] - 17s 213ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 65/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 66/100
# 80/80 [==============================] - 17s 214ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 67/100
# 80/80 [==============================] - 17s 213ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 68/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0015 - val_loss: 7.5943e-04
# Epoch 69/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0012 - val_loss: 6.6362e-04
# Epoch 70/100
# 80/80 [==============================] - 17s 214ms/step - loss: 0.0011 - val_loss: 5.3492e-04
# Epoch 71/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0010 - val_loss: 5.0866e-04
# Epoch 72/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0010 - val_loss: 7.0883e-04
# Epoch 73/100
# 80/80 [==============================] - 17s 214ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 74/100
# 80/80 [==============================] - 17s 215ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 75/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 76/100
# 80/80 [==============================] - 17s 216ms/step - loss: 0.0017 - val_loss: 0.0055
# Epoch 77/100
# 80/80 [==============================] - 17s 214ms/step - loss: 0.0020 - val_loss: 0.0058
# Epoch 78/100
# 80/80 [==============================] - 17s 215ms/step - loss: 0.0019 - val_loss: 0.0061
# Epoch 79/100
# 80/80 [==============================] - 17s 216ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 80/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 81/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0015 - val_loss: 9.1979e-04
# Epoch 82/100
# 80/80 [==============================] - 17s 214ms/step - loss: 0.0011 - val_loss: 5.5205e-04
# Epoch 83/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0012 - val_loss: 4.7405e-04
# Epoch 84/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0012 - val_loss: 6.8986e-04
# Epoch 85/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 86/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 87/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 88/100
# 80/80 [==============================] - 17s 206ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 89/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 90/100
# 80/80 [==============================] - 17s 211ms/step - loss: 0.0020 - val_loss: 0.0063
# Epoch 91/100
# 80/80 [==============================] - 17s 208ms/step - loss: 0.0020 - val_loss: 0.0060
# Epoch 92/100
# 80/80 [==============================] - 17s 210ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 93/100
# 80/80 [==============================] - 17s 213ms/step - loss: 0.0018 - val_loss: 7.2360e-04
# Epoch 94/100
# 80/80 [==============================] - 17s 217ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 95/100
# 80/80 [==============================] - 17s 212ms/step - loss: 0.0013 - val_loss: 5.6913e-04
# Epoch 96/100
# 80/80 [==============================] - 17s 207ms/step - loss: 0.0012 - val_loss: 9.6984e-04
# Epoch 97/100
# 80/80 [==============================] - 17s 212ms/step - loss: 7.6772e-04 - val_loss: 6.1328e-04
# Epoch 98/100
# 80/80 [==============================] - 17s 216ms/step - loss: 7.9022e-04 - val_loss: 7.4949e-04
# Epoch 99/100
# 80/80 [==============================] - 17s 211ms/step - loss: 7.9395e-04 - val_loss: 4.9014e-04
# Epoch 100/100
# 80/80 [==============================] - 17s 214ms/step - loss: 7.3635e-04 - val_loss: 4.2000e-04

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history["loss"], label= "train loss")
plt.plot(history.history["val_loss"], label= "validation loss")
plt.ylabel("Average Loss")
plt.legend()

# %%
#Lets do the prediction and performance checking

X_train_predict = model.predict(X_train)
X_test_predict = model.predict(X_test)

# %%
#transformation to original form

y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
X_train_predict_inv = scaler.inverse_transform(X_train_predict)
X_test_predict_inv = scaler.inverse_transform(X_test_predict)

# %%
plt.figure(figsize=(16,7))
plt.plot(y_train_inv.flatten(), marker='.', label="Actual")
plt.plot(X_train_predict_inv.flatten(), 'r', marker='.', label="Predicted")
plt.ylabel("BitCoin Price")
plt.title("Comparision between Predicted train and Target Train data ")

plt.legend()

# %%
plt.figure(figsize=(16,7))
plt.plot(y_test_inv.flatten(), marker='.', label="Actual")
plt.plot(X_test_predict_inv.flatten(), 'r', marker='.', label="Predicted")
plt.ylabel("BitCoin Price")
plt.title("Comparision between Predicted Test and Target Test data ")
plt.legend()

# %%
y_test_inv.flatten()
# Out:
# array([ 6976.30624203,  6871.94345909,  6947.87803   ,  6751.70685631,
#         6884.61106872,  6801.8162349 ,  6912.4954132 ,  7071.97079441,
#         7152.37871189,  7167.8373069 ,  7052.47481895,  6867.56422278,
#         7000.48837044,  7294.03035521,  7521.66496367,  7546.96929677,
#         7601.42011381,  7715.97716508,  7730.79847711,  8244.81773005,
#         8894.27598485,  8784.23729479,  8873.30749644,  8980.49813109,
#         8772.6056095 ,  8930.89784977,  9162.65638208,  9490.68228907,
#         9924.47161151,  9727.26452001,  8687.5145762 ,  8706.86781146,
#         8774.17437174,  9045.37065621,  9576.83866785,  9523.70146861,
#         9403.52863179,  9624.59008178,  9721.80981213,  9670.29856205,
#         9672.22024027,  9280.30452694,  9125.38938388,  9207.08634835,
#         9123.70367205,  8819.56776795,  8859.68461494,  9027.30330797,
#         9320.29837284,  9454.40027718,  9507.15768977,  9547.07079084,
#         9584.67368651,  9880.13007309,  9551.65622781,  9699.75304439,
#         9742.43330403,  9636.42490419,  9621.18100519,  9725.86572807,
#         9712.5378641 ,  9787.97916764,  9643.77074998,  9411.22799497,
#         9426.95793026,  9404.45492419,  9244.63674311,  9493.82322488,
#         9443.08982841,  9406.31222964,  9326.55623233,  9301.52108075,
#         9348.61076253,  9480.84017757,  9638.23618163,  9440.90571449,
#         9231.63743639,  9181.18916299,  9107.37717627,  9055.22655758,
#         9116.18617657,  9150.96730237,  9191.3131156 ,  9166.91215183,
#         9093.97642278,  9091.43477019,  9064.24836837,  9212.5648659 ,
#         9269.20883555,  9345.54211179,  9329.72893979,  9200.01730658,
#         9239.07184869,  9249.80798004,  9278.31272851,  9220.18001813,
#         9221.8688333 ,  9132.12458948,  9134.67578591,  9161.91614235,
#         9154.98831604,  9177.83802636,  9307.5144248 ,  9365.63097453,
#         9541.05375132,  9557.22862725,  9619.53941653,  9833.75766355,
#        10435.0204352 , 10985.11959269, 11096.01892714, 11033.57612881,
#        11196.08253068, 11609.29992058, 11333.15936833, 11254.70375534,
#        11243.64566538, 11465.1052734 , 11755.5811998 , 11716.45454163,
#        11684.85108767, 11672.63996389, 11899.98963989, 11632.95957901,
#        11463.75262378, 11550.92199986, 11755.18920418, 11877.0066112 ,
#        11850.90548024, 12055.30370288, 12164.47122787, 11797.51651098,
#        11799.36729641, 11744.31599715, 11559.96281934, 11620.87430314,
#        11733.99630954, 11508.90678998, 11403.61002318, 11346.29996108,
#        11442.45954769, 11507.26337684, 11608.74760756, 11685.00337073,
#        11874.70306633, 11576.82064488, 11039.34035189, 10391.27609007,
#        10269.15681986, 10201.62230163, 10160.40145998, 10147.86515633,
#        10188.1071722 , 10339.3483632 , 10303.17669293, 10373.14298677,
#        10395.79815615])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

train_RMSE = np.sqrt(mean_squared_error(y_train, X_train_predict))
test_RMSE = np.sqrt(mean_squared_error(y_test, X_test_predict))
train_MAE = np.sqrt(mean_absolute_error(y_train, X_train_predict))
test_MAE = np.sqrt(mean_absolute_error(y_test, X_test_predict))


print(f"Train RMSE: {train_RMSE}")
print(f"Train MAE: {train_MAE}")

print(f"Test RMSE: {test_RMSE}")
print(f"Test MAE: {test_MAE}")
# Out:
# Train RMSE: 0.03786759968746118
# Train MAE: 0.18440016332992654
# Test RMSE: 0.015289931358133045
# Test MAE: 0.1036809309837744

# %%
from sklearn.metrics import r2_score

# %%
print('R2 Score : ','{:.2%}'.format(r2_score(y_test_inv,X_test_predict_inv )))
# Out:
# R2 Score :  95.29%

# %%
results = model.evaluate(X_test_predict_inv, y_test_inv, batch_size=1)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 100, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (1, 1, 1).
# 157/157 [==============================] - 2s 3ms/step - loss: 95169960.0000
